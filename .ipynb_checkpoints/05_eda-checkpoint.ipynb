# %%
## DO I NEED TO CONVERT NUMERIC FEATURES (BEDS, BATHS, FLOORS, ETC) INTO STR FEATURES TO CREATE DUMMY/CATEGORICAL?
## DUMMY VARIABLES FOR BOOLEAN FEATURES - LAUNDRY, HEATING, A/C, POOL?
## POLYNOMIAL TRANSFORMATIONS?
## INTERACTION TRANSFORMATIONS? - See linreg_feateng_chap_4_exercises.ipynb
## LOG TRANSFORMATION CONSIDERATIONS? TARGET, FEATURES, ETC

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

from scipy import stats

# %%
df=pd.read_csv('redfin_data.csv')

# %%
df.shape
# Out:
# (1656, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1656 entries, 0 to 1655
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sold Price         1649 non-null   float64
#  1   Beds               1649 non-null   float64
#  2   Baths              1649 non-null   float64
#  3   Floors             1632 non-null   float64
#  4   Garage Spaces      1656 non-null   int64
#  5   Lot Size (sq ft)   1653 non-null   float64
#  6   Home Size (sq ft)  1655 non-null   float64
#  7   Year Built         1653 non-null   float64
#  8   School Score Avg   1515 non-null   float64
#  9   Walk Score         1538 non-null   float64
#  10  Transit Score      1538 non-null   float64
#  11  Bike Score         1538 non-null   float64
#  12  Laundry            1656 non-null   bool
#  13  Heating            1656 non-null   bool
#  14  Air Conditioning   1656 non-null   bool
#  15  Pool               1656 non-null   bool
# ...

# %%
## clean data

df.drop(columns=['Address', 'Sold Status', 'URL'], inplace = True)

df = df.dropna()
df.reset_index(drop=True, inplace=True)

df.columns= df.columns.str.lower()
df.rename(columns={'lot size (sq ft)': 'lot size', 'home size (sq ft)': 'home size'}, inplace=True)

df.drop(df.index[df['city'] == 'SAN JOSE'], inplace=True)

df.drop(df.index[df['city'] == 'EAST PALO ALTO'], inplace=True)

df.drop(df.index[df['county'] == 'SAN MATEO COUNTY'], inplace=True)

df.drop(columns=['county', 'zip code', 'property type'], inplace = True)

df['age of house'] = (df['year built'].max() + 1) - df['year built']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 0 to 1439
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1297 non-null   float64
#  1   beds              1297 non-null   float64
#  2   baths             1297 non-null   float64
#  3   floors            1297 non-null   float64
#  4   garage spaces     1297 non-null   int64
#  5   lot size          1297 non-null   float64
#  6   home size         1297 non-null   float64
#  7   year built        1297 non-null   float64
#  8   school score avg  1297 non-null   float64
#  9   walk score        1297 non-null   float64
#  10  transit score     1297 non-null   float64
#  11  bike score        1297 non-null   float64
#  12  laundry           1297 non-null   bool
#  13  heating           1297 non-null   bool
#  14  air conditioning  1297 non-null   bool
#  15  pool              1297 non-null   bool
# ...

# %%
## prepare temp df to explore data via pairplot
df_temp = df.drop(columns=['year built', 'walk score', 'transit score', 'bike score',
                           'city', 'laundry', 'heating', 'air conditioning', 'pool'])

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 0 to 1439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1297 non-null   float64
#  1   beds              1297 non-null   float64
#  2   baths             1297 non-null   float64
#  3   floors            1297 non-null   float64
#  4   garage spaces     1297 non-null   int64
#  5   lot size          1297 non-null   float64
#  6   home size         1297 non-null   float64
#  7   school score avg  1297 non-null   float64
#  8   age of house      1297 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 101.3 KB

# %%
## examine pairplot for outliers, distributions, relationships, zeros
sns.pairplot(df_temp);

# %%
## feature exploration
## explore/investigate potential outliers 2+ std from the mean

# %%
df_temp['sold price'].describe()
# Out:
# count    1.297000e+03
# mean     3.042164e+06
# std      1.260630e+06
# min      7.750000e+05
# 25%      2.100000e+06
# 50%      2.828000e+06
# 75%      3.709113e+06
# max      1.380700e+07
# Name: sold price, dtype: float64

# %%
df_temp.sort_values(by=['sold price'], ascending=False)

# remove outlier?
# Out:
#       sold price  beds  baths  floors  garage spaces   lot size  home size  \
# 126   13807000.0   5.0    7.0     2.0              2  10497.960     5366.0
# 1326  10000000.0   5.0    4.5     3.0              2  14671.008     7536.0
# 105    9800000.0   7.0    6.5     2.0              2  11913.660     6304.0
# 344    8592002.0   5.0    5.0     2.0              0   6734.376     4708.0
# 1325   8500000.0   4.0    5.5     1.0              2  19074.924     4079.0
# ...          ...   ...    ...     ...            ...        ...        ...
# 1201   1105000.0   2.0    1.0     1.0              1   4321.152      864.0
# 1085   1020000.0   3.0    2.0     1.0              0   4499.748      880.0
# 1036   1000000.0   3.0    1.0     1.0              1   3384.612      937.0
# 1187    928000.0   2.0    2.5     2.0              1   1097.712     1126.0
# 1161    775000.0   2.0    1.0     1.0              0   7649.136      863.0
#
#       school score avg  age of house
# ...

# %%
df_temp.drop([126], inplace=True)
df_temp.sort_values(by=['sold price'], ascending=False)
# Out:
#       sold price  beds  baths  floors  garage spaces   lot size  home size  \
# 1326  10000000.0   5.0    4.5     3.0              2  14671.008     7536.0
# 105    9800000.0   7.0    6.5     2.0              2  11913.660     6304.0
# 344    8592002.0   5.0    5.0     2.0              0   6734.376     4708.0
# 1325   8500000.0   4.0    5.5     1.0              2  19074.924     4079.0
# 327    8010300.0   7.0    6.5     2.0              0   6734.376     6200.0
# ...          ...   ...    ...     ...            ...        ...        ...
# 1201   1105000.0   2.0    1.0     1.0              1   4321.152      864.0
# 1085   1020000.0   3.0    2.0     1.0              0   4499.748      880.0
# 1036   1000000.0   3.0    1.0     1.0              1   3384.612      937.0
# 1187    928000.0   2.0    2.5     2.0              1   1097.712     1126.0
# 1161    775000.0   2.0    1.0     1.0              0   7649.136      863.0
#
#       school score avg  age of house
# ...

# %%
df_temp.sort_values(by=['sold price'], ascending=True)
# Out:
#       sold price  beds  baths  floors  garage spaces   lot size  home size  \
# 1161    775000.0   2.0    1.0     1.0              0   7649.136      863.0
# 1187    928000.0   2.0    2.5     2.0              1   1097.712     1126.0
# 1036   1000000.0   3.0    1.0     1.0              1   3384.612      937.0
# 1085   1020000.0   3.0    2.0     1.0              0   4499.748      880.0
# 1201   1105000.0   2.0    1.0     1.0              1   4321.152      864.0
# ...          ...   ...    ...     ...            ...        ...        ...
# 327    8010300.0   7.0    6.5     2.0              0   6734.376     6200.0
# 1325   8500000.0   4.0    5.5     1.0              2  19074.924     4079.0
# 344    8592002.0   5.0    5.0     2.0              0   6734.376     4708.0
# 105    9800000.0   7.0    6.5     2.0              2  11913.660     6304.0
# 1326  10000000.0   5.0    4.5     3.0              2  14671.008     7536.0
#
#       school score avg  age of house
# ...

# %%
df_temp['beds'].describe()
# Out:
# count    1296.000000
# mean        3.614969
# std         0.868527
# min         1.000000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         7.000000
# Name: beds, dtype: float64

# %%
df_temp['baths'].describe()
# Out:
# count    1296.000000
# mean        2.467593
# std         0.929624
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         7.500000
# Name: baths, dtype: float64

# %%
df_temp['floors'].describe()
# Out:
# count    1296.000000
# mean        1.291667
# std         0.500000
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: floors, dtype: float64

# %%
df_temp['garage spaces'].describe()
# Out:
# count    1296.000000
# mean        1.432099
# std         0.867262
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: garage spaces, dtype: float64

# %%
df_temp['lot size'].describe()
# Out:
# count      1296.000000
# mean       7582.814556
# std        6372.358592
# min           0.000000
# 25%        5684.580000
# 50%        6682.104000
# 75%        8297.091000
# max      146361.600000
# Name: lot size, dtype: float64

# %%
df_temp['home size'].describe()
# Out:
# count    1296.000000
# mean     1897.905864
# std       780.387891
# min       528.000000
# 25%      1355.250000
# 50%      1740.000000
# 75%      2263.250000
# max      7536.000000
# Name: home size, dtype: float64

# %%
df_temp['school score avg'].describe()
# Out:
# count    1296.000000
# mean        7.297197
# std         1.249140
# min         4.000000
# 25%         6.333333
# 50%         7.666667
# 75%         8.333333
# max         9.333333
# Name: school score avg, dtype: float64

# %%
df_temp['age of house'].describe()
# Out:
# count    1296.000000
# mean       59.719136
# std        22.438002
# min         1.000000
# 25%        55.000000
# 50%        66.000000
# 75%        70.250000
# max       130.000000
# Name: age of house, dtype: float64

# %%
df_temp['beds'].value_counts()

# remove outliers? bucket 6+?
# Out:
# 3.0    576
# 4.0    457
# 5.0    163
# 2.0     70
# 6.0     24
# 7.0      4
# 1.0      2
# Name: beds, dtype: int64

# %%
df_temp['baths'].value_counts()

# bucket 5+?
# Out:
# 2.0    583
# 3.0    239
# 2.5    161
# 1.0    109
# 4.0     59
# 3.5     56
# 4.5     37
# 1.5     21
# 5.0     15
# 6.5      6
# 6.0      5
# 5.5      4
# 7.5      1
# Name: baths, dtype: int64

# %%
df_temp['floors'].value_counts()
# Out:
# 1.0    946
# 2.0    322
# 3.0     28
# Name: floors, dtype: int64

# %%
df_temp['garage spaces'].value_counts()

# bucket3+?
# Out:
# 2    777
# 0    287
# 1    199
# 3     29
# 4      4
# Name: garage spaces, dtype: int64

# %%
df_temp.sort_values(by=['lot size'], ascending=False)

# remove outliers
# Out:
#       sold price  beds  baths  floors  garage spaces    lot size  home size  \
# 951    3888000.0   4.0    3.0     1.0              2  146361.600     2187.0
# 952    3950000.0   4.0    2.5     1.0              2  146361.600     2071.0
# 165    6200000.0   4.0    2.0     1.0              0   43703.748     2411.0
# 948    3900000.0   4.0    2.5     1.0              2   28880.280     2182.0
# 866    3900000.0   4.0    2.5     1.0              2   28880.280     2182.0
# ...          ...   ...    ...     ...            ...         ...        ...
# 1256   1884020.0   3.0    3.5     3.0              2    1398.276     2231.0
# 800    1818000.0   4.0    3.5     2.0              2    1319.868     1725.0
# 494    1600000.0   3.0    3.5     3.0              2    1306.800     1612.0
# 1187    928000.0   2.0    2.5     2.0              1    1097.712     1126.0
# 1410   2950000.0   2.0    2.0     1.0              0       0.000     1318.0
#
#       school score avg  age of house
# ...

# %%
df_temp.drop([951,952], inplace=True)
df_temp.sort_values(by=['lot size'], ascending=False)
# Out:
#       sold price  beds  baths  floors  garage spaces   lot size  home size  \
# 165    6200000.0   4.0    2.0     1.0              0  43703.748     2411.0
# 866    3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 948    3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 1383   3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 293    6700000.0   6.0    6.5     3.0              4  25944.336     6338.0
# ...          ...   ...    ...     ...            ...        ...        ...
# 1256   1884020.0   3.0    3.5     3.0              2   1398.276     2231.0
# 800    1818000.0   4.0    3.5     2.0              2   1319.868     1725.0
# 494    1600000.0   3.0    3.5     3.0              2   1306.800     1612.0
# 1187    928000.0   2.0    2.5     2.0              1   1097.712     1126.0
# 1410   2950000.0   2.0    2.0     1.0              0      0.000     1318.0
#
#       school score avg  age of house
# ...

# %%
df_temp.sort_values(by=['lot size'], ascending=True)
# Out:
#       sold price  beds  baths  floors  garage spaces   lot size  home size  \
# 1410   2950000.0   2.0    2.0     1.0              0      0.000     1318.0
# 1187    928000.0   2.0    2.5     2.0              1   1097.712     1126.0
# 494    1600000.0   3.0    3.5     3.0              2   1306.800     1612.0
# 800    1818000.0   4.0    3.5     2.0              2   1319.868     1725.0
# 1256   1884020.0   3.0    3.5     3.0              2   1398.276     2231.0
# ...          ...   ...    ...     ...            ...        ...        ...
# 1418   6700000.0   6.0    6.5     3.0              4  25944.336     6338.0
# 1383   3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 948    3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 866    3900000.0   4.0    2.5     1.0              2  28880.280     2182.0
# 165    6200000.0   4.0    2.0     1.0              0  43703.748     2411.0
#
#       school score avg  age of house
# ...

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 0 to 1439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1294 non-null   float64
#  1   beds              1294 non-null   float64
#  2   baths             1294 non-null   float64
#  3   floors            1294 non-null   float64
#  4   garage spaces     1294 non-null   int64
#  5   lot size          1294 non-null   float64
#  6   home size         1294 non-null   float64
#  7   school score avg  1294 non-null   float64
#  8   age of house      1294 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 101.1 KB

# %%
df_temp['age of house'].describe()
# Out:
# count    1294.000000
# mean       59.710974
# std        22.453835
# min         1.000000
# 25%        55.000000
# 50%        66.000000
# 75%        70.750000
# max       130.000000
# Name: age of house, dtype: float64

# %%
df_temp['age of house'].unique()
# Out:
# array([ 96., 112.,  63.,  71.,  98.,  99.,  75.,   2.,  72.,  26.,  15.,
#         73.,  68.,  20.,  55.,  81.,  21.,  87.,  46.,  66.,  69.,  76.,
#         77.,  12., 130.,  27.,  74.,  70.,  62.,  22.,  24.,  67.,  97.,
#          3.,  92.,   1.,  36.,  64.,  50.,  93.,  59.,  30.,  65.,   6.,
#         23.,  38.,  11.,  88.,  95., 101.,  91.,  61., 100.,  19.,  78.,
#         10.,  60., 115.,  53.,  58.,  83.,  85.,  18.,  17.,  14.,  13.,
#        116., 113., 108.,  35., 103.,  39., 123.,  56.,  37.,  57.,  79.,
#         51.,  34., 106.,  47.,  45.,  29.,  48., 111.,   4.,   5.,  25.,
#         28.,  16.,   7.,  31.,  54.,  42.,  82.,  80.,  49.,   8.,  44.,
#         33.,  41.,  52., 120., 118., 117., 107., 114.])

# %%
sns.pairplot(df_temp);

# %%
df_temp.corr()
# Out:
#                   sold price      beds     baths    floors  garage spaces  \
# sold price          1.000000  0.529879  0.608531  0.295516       0.070814
# beds                0.529879  1.000000  0.684602  0.419411       0.160188
# baths               0.608531  0.684602  1.000000  0.517562       0.109552
# floors              0.295516  0.419411  0.517562  1.000000       0.101562
# garage spaces       0.070814  0.160188  0.109552  0.101562       1.000000
# lot size            0.494726  0.288077  0.229753 -0.050514       0.197621
# home size           0.776354  0.729638  0.825037  0.536095       0.153579
# school score avg    0.637237  0.243905  0.247345  0.141336       0.063769
# age of house       -0.261373 -0.314220 -0.468019 -0.488216      -0.157471
#
#                   lot size  home size  school score avg  age of house
# sold price        0.494726   0.776354          0.637237     -0.261373
# beds              0.288077   0.729638          0.243905     -0.314220
# ...

# %%
## 'bucket' observations for beds [1, 2, 3, 4, 5, 6+]?
## 'bucket' observations for baths [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5+]?
## 'bucket' observations for garage spaces [0, 1, 2, 3+]?

## consider dummy variables for beds, baths, floors, garage spaces

# %%
df_copy = df_temp.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 0 to 1439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1294 non-null   float64
#  1   beds              1294 non-null   float64
#  2   baths             1294 non-null   float64
#  3   floors            1294 non-null   float64
#  4   garage spaces     1294 non-null   int64
#  5   lot size          1294 non-null   float64
#  6   home size         1294 non-null   float64
#  7   school score avg  1294 non-null   float64
#  8   age of house      1294 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 133.4 KB

# %%
df_copy['garage spaces'] = df_copy['garage spaces'].map(str)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 0 to 1439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1294 non-null   float64
#  1   beds              1294 non-null   float64
#  2   baths             1294 non-null   float64
#  3   floors            1294 non-null   float64
#  4   garage spaces     1294 non-null   object
#  5   lot size          1294 non-null   float64
#  6   home size         1294 non-null   float64
#  7   school score avg  1294 non-null   float64
#  8   age of house      1294 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 133.4+ KB

# %%
df_copy['garage spaces'].value_counts()
# Out:
# 2    775
# 0    287
# 1    199
# 3     29
# 4      4
# Name: garage spaces, dtype: int64

# %%
garage_counts = df_copy['garage spaces'].value_counts()
garage_counts
# Out:
# 2    775
# 0    287
# 1    199
# 3     29
# 4      4
# Name: garage spaces, dtype: int64

# %%
three_plus = list(garage_counts[garage_counts <= 30].index)
three_plus
# Out:
# ['3', '4']

# %%
df_copy['garage spaces'] = df_copy['garage spaces'].replace(three_plus, '3+')
df_copy['garage spaces'].value_counts()
# Out:
# 2     775
# 0     287
# 1     199
# 3+     33
# Name: garage spaces, dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 0 to 1439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1294 non-null   float64
#  1   beds              1294 non-null   float64
#  2   baths             1294 non-null   float64
#  3   floors            1294 non-null   float64
#  4   garage spaces     1294 non-null   object
#  5   lot size          1294 non-null   float64
#  6   home size         1294 non-null   float64
#  7   school score avg  1294 non-null   float64
#  8   age of house      1294 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 133.4+ KB

# %%
dummies = pd.get_dummies(df_copy, drop_first=True)

# %%
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 0 to 1439
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sold price        1294 non-null   float64
#  1   beds              1294 non-null   float64
#  2   baths             1294 non-null   float64
#  3   floors            1294 non-null   float64
#  4   lot size          1294 non-null   float64
#  5   home size         1294 non-null   float64
#  6   school score avg  1294 non-null   float64
#  7   age of house      1294 non-null   float64
#  8   garage spaces_1   1294 non-null   uint8
#  9   garage spaces_2   1294 non-null   uint8
#  10  garage spaces_3+  1294 non-null   uint8
# dtypes: float64(8), uint8(3)
# memory usage: 127.1 KB

# %%
# plt.figure(figsize=(12,12))

# data = df[['sold_price', 'beds', 'baths', 'hm_sqft', 'lot_size', 'yr_built']]
# g = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True, linewidth=1, linecolor='black', 
#             annot_kws={"size": 16, 'fontweight': 'bold'}, square=True)
# g.set_xticklabels(g.get_xticklabels(), rotation=30, size=14, fontweight='bold')
# g.set_yticklabels(g.get_yticklabels(), rotation=30, size=14, fontweight='bold')
# cbar = g.collections[0].colorbar
# cbar.ax.tick_params(labelsize=14);

# %%
sns.histplot(data=df_temp['sold price']);

# %%
sns.histplot(data=np.log10(df_temp['sold price']));
